# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
negatives = test[test['Predicted']<=0]

# %%
negatives
# Out:
#       Actual  Predicted  Diviation     model    year transmission   mileage  \
# 131   5297.0    -265.65    5562.65     Focus  2013.0       Manual   69420.0
# 336   2495.0   -7647.23   10142.23   C Class  2005.0    Automatic  110461.0
# 396   4689.0   -5500.50   10189.50        A3  2004.0    Automatic   28477.0
# 448   1495.0  -10927.57   12422.57     Focus  2006.0       Manual  105000.0
# 595   1450.0  -11147.36   12597.36     Focus  2007.0       Manual  100100.0
# ...      ...        ...        ...       ...     ...          ...       ...
# 6243  2295.0   -3481.82    5776.82     Focus  2008.0       Manual   81000.0
# 6304  2895.0   -2672.27    5567.27     Focus  2007.0    Automatic   54000.0
# 6371  1575.0   -3134.66    4709.66     Focus  2003.0    Automatic  111000.0
# 6506  1575.0   -4107.13    5682.13     Focus  2005.0       Manual   90000.0
# 6624  1475.0   -2516.75    3991.75     Focus  2005.0    Automatic   88746.0
#
#      fuel type  engine size
# ...

# %%
test.hist(bins=15, color='steelblue', edgecolor='black', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %%
fig = plt.figure(figsize = (6,4))
title = fig.suptitle('Deviation', fontsize=14)
fig.subplots_adjust(top=0.86, wspace=0.3)

ax = fig.add_subplot(1,1, 1)
ax.set_xlabel('mileage')
ax.set_ylabel('Deviation') 
ax.text(1.2, 800, r'$\mu$='+str(round(test['Diviation'].mean(),2)), 
         fontsize=12)
freq, bins, patches = ax.hist(test['Diviation'], color='steelblue', bins=15,
                                    edgecolor='black', linewidth=1)
                                    

# Density Plot # kernel density estimate
fig = plt.figure(figsize = (6, 4))
title = fig.suptitle('Deviation', fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,1, 1)
ax1.set_xlabel('Deviation')
ax1.set_ylabel('Frequency') 
sns.kdeplot(test['Diviation'], ax=ax1, shade=True, color='steelblue')
# Out:
# <AxesSubplot:xlabel='Deviation', ylabel='Frequency'>

# %%
f, ax = plt.subplots(figsize=(10, 6))
corr = test.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Correlation Heatmap', fontsize=14)

# %%
cols = ['density', 'residual sugar', 'total sulfur dioxide', 'fixed acidity']
pp = sns.pairplot(wines[cols], height=1.8, aspect=1.8,
                  plot_kws=dict(edgecolor="k", linewidth=0.5),
                  diag_kind="kde", diag_kws=dict(shade=True))

fig = pp.fig 
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Wine Attributes Pairwise Plots', fontsize=14)

# %%
plt.scatter(test['mileage'], test['Predicted'],
            alpha=0.4, edgecolors='w')

plt.xlabel('mileage')
plt.ylabel('Predicted')
plt.title('Mileage - Predicted',y=1.05)


# Joint Plot
jp = sns.jointplot(x='mileage', y='Predicted', data=test,
                   kind='reg', space=0, height=5, ratio=4)

# %%
fig = plt.figure(figsize = (10,4))
title = fig.suptitle("Mileage", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,2, 1)
ax1.set_xlabel("Mileage")
ax1.set_ylabel("Frequency") 
ax1.set_ylim([0, 1200])
ax1.text(1.2, 800, r'$\mu$='+str(round(test['mileage'].mean(),2)), 
         fontsize=12)
r_freq, r_bins, r_patches = ax1.hist(test['mileage'], color='red', bins=15,
                                     edgecolor='black', linewidth=1)


# facets with density plots
fig = plt.figure(figsize = (10, 4))
title = fig.suptitle("Mileage", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,2, 1)
ax1.set_xlabel("Mileage")
ax1.set_ylabel("Density") 
sns.kdeplot(test['mileage'], ax=ax1, shade=True, color='r')
# Out:
# <AxesSubplot:xlabel='Mileage', ylabel='Density'>

# %%
#I think the problem comes from the mileage variable
